# %%
import os

# Set up the Snowflake and PostgreSQL data sources
SNOWFLAKE_USER = os.environ.get("SNOWFLAKE_USER")
SNOWFLAKE_PASSWORD = os.environ.get("SNOWFLAKE_PASSWORD")
SNOWFLAKE_ACCOUNT = os.environ.get("SNOWFLAKE_ACCOUNT")
SNOWFLAKE_WAREHOUSE = os.environ.get("SNOWFLAKE_WAREHOUSE")
SNOWFLAKE_DATABASE = os.environ.get("SNOWFLAKE_DATABASE")
SNOWFLAKE_SCHEMA = os.environ.get("SNOWFLAKE_SCHEMA")
SNOWFLAKE_ROLE = os.environ.get("SNOWFLAKE_ROLE")

# %%
import logging
import sys

date_strftime_format = "%Y-%m-%y %H:%M:%S"
logging.basicConfig(
    stream=sys.stdout,
    level=logging.INFO,
    format="%(asctime)s %(message)s",
    datefmt=date_strftime_format,
)

# %%
from aita.datasource.snowflake import SnowflakeDataSource

sf_datasource = SnowflakeDataSource(
    user=SNOWFLAKE_USER,
    password=SNOWFLAKE_PASSWORD,
    account=SNOWFLAKE_ACCOUNT,
    warehouse=SNOWFLAKE_WAREHOUSE,
    database=SNOWFLAKE_DATABASE,
    db_schema=SNOWFLAKE_SCHEMA,
    role="ACCOUNTADMIN",
)

# %%
# sf_datasource.execute("select * from SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.orders limit 3")

# %%
from databuilder.loader.generic_loader import GenericLoader

# %%
sf_datasource.crawl_data_catalog(loader=GenericLoader())
# Out:
# 2024-07-24 20:53:56 Crawling Snowflake data catalog
# 2024-07-24 20:53:56 Creating Snowflake metadata extraction job
# 2024-07-24 20:53:56 Running Snowflake metadata extraction job
# 2024-07-24 20:53:56 Launching a job
# 2024-07-24 20:53:56 SQL for snowflake metadata:
#     SELECT
#         lower(c.column_name) AS col_name,
#         c.comment AS col_description,
#         lower(c.data_type) AS col_type,
#         lower(c.ordinal_position) AS col_sort_order,
#         lower(c.table_catalog) AS database,
#         lower(c.table_catalog) AS cluster,
#         lower(c.table_schema) AS schema,
#         lower(c.table_name) AS name,
#         t.comment AS description,
#         decode(lower(t.table_type), 'view', 'true', 'false') AS is_view
#     FROM
#         SNOWFLAKE_SAMPLE_DATA.INFORMATION_SCHEMA.COLUMNS AS c
#     LEFT JOIN
#         SNOWFLAKE_SAMPLE_DATA.INFORMATION_SCHEMA.TABLES t
#             ON c.TABLE_NAME = t.TABLE_NAME
#             AND c.TABLE_SCHEMA = t.TABLE_SCHEMA
#     ;
#
# 2024-07-24 20:53:56 Snowflake Connector for Python Version: 3.12.0, Python Version: 3.12.3, Platform: macOS-14.0-arm64-arm-64bit
# 2024-07-24 20:53:56 Connecting to GLOBAL Snowflake domain
# 2024-07-24 20:53:56 This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# /Users/haoxu/Library/Caches/pypoetry/virtualenvs/aita-YD6hEonJ-py3.12/lib/python3.12/site-packages/snowflake/sqlalchemy/base.py:1068: SAWarning: The GenericFunction 'flatten' is already registered and is going to be overridden.
#   functions.register_function("flatten", flatten)
# 2024-07-24 20:53:57 Number of results in first chunk: 1
# 2024-07-24 20:53:57 Number of results in first chunk: 1
# 2024-07-24 20:53:59 Number of results in first chunk: 521
# 2024-07-24 20:53:59 Running a task
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_comment', None, 'text', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_nationkey', None, 'number', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'customer_address' None, [ColumnMetadata('ca_street_name', None, 'text', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_sales' None, [ColumnMetadata('cs_bill_hdemo_sk', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer_demographics' None, [ColumnMetadata('cd_dep_employed_count', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_returns' None, [ColumnMetadata('wr_item_sk', None, 'number', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_retailprice', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_tax', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'date_dim' None, [ColumnMetadata('d_same_day_lq', None, 'number', '23', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_bill_hdemo_sk', None, 'number', '7', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_page' None, [ColumnMetadata('wp_autogen_flag', None, 'text', '7', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'inventory' None, [ColumnMetadata('inv_date_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'warehouse' None, [ColumnMetadata('w_county', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_ship_cdemo_sk', None, 'number', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_suppkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'time_dim' None, [ColumnMetadata('t_meal_time', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_return_ship_cost', None, 'number', '23', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'call_center' None, [ColumnMetadata('cc_rec_end_date', None, 'date', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'promotion' None, [ColumnMetadata('p_channel_email', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_discount', None, 'number', '7', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'ship_mode' None, [ColumnMetadata('sm_type', None, 'text', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_page' None, [ColumnMetadata('wp_web_page_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'customer' DescriptionMetadata('description', 'Customer data as defined by TPC-H'), [ColumnMetadata('c_name', None, 'text', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store_sales' None, [ColumnMetadata('ss_promo_sk', None, 'number', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_sales' None, [ColumnMetadata('ss_ext_sales_price', None, 'number', '16', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_orderstatus', None, 'text', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_ship_addr_sk', None, 'number', '12', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer_demographics' None, [ColumnMetadata('cd_dep_college_count', None, 'number', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_returns' None, [ColumnMetadata('wr_refunded_customer_sk', None, 'number', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_ship_hdemo_sk', None, 'number', '11', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_brand', None, 'text', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_phone', None, 'text', '5', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_sales' None, [ColumnMetadata('cs_bill_cdemo_sk', None, 'number', '5', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_site' None, [ColumnMetadata('web_open_date_sk', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer_demographics' None, [ColumnMetadata('cd_dep_count', None, 'number', '7', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_ext_wholesale_cost', None, 'number', '25', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_custkey', None, 'number', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'household_demographics' None, [ColumnMetadata('hd_demo_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'warehouse' None, [ColumnMetadata('w_city', None, 'text', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_quantity', None, 'number', '19', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'household_demographics' None, [ColumnMetadata('hd_income_band_sk', None, 'number', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'date_dim' None, [ColumnMetadata('d_fy_quarter_seq', None, 'number', '13', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_shipmode', None, 'text', '15', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store' None, [ColumnMetadata('s_city', None, 'text', '23', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_sales' None, [ColumnMetadata('cs_net_paid_inc_tax', None, 'number', '31', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'date_dim' None, [ColumnMetadata('d_date_id', None, 'text', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'partsupp' DescriptionMetadata('description', 'Partsupp data as defined by TPC-H'), [ColumnMetadata('ps_suppkey', None, 'number', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_orderkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'date_dim' None, [ColumnMetadata('d_fy_week_seq', None, 'number', '14', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_page' None, [ColumnMetadata('cp_catalog_page_id', None, 'text', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_sales' None, [ColumnMetadata('cs_ship_customer_sk', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_tax', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'region' DescriptionMetadata('description', 'Region data as defined by TPC-H'), [ColumnMetadata('r_comment', None, 'text', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_shipinstruct', None, 'text', '14', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_orderkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'date_dim' None, [ColumnMetadata('d_current_quarter', None, 'text', '27', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'date_dim' None, [ColumnMetadata('d_last_dom', None, 'number', '21', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'partsupp' DescriptionMetadata('description', 'Partsupp data as defined by TPC-H'), [ColumnMetadata('ps_comment', None, 'text', '5', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_page' None, [ColumnMetadata('cp_type', None, 'text', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'call_center' None, [ColumnMetadata('cc_gmt_offset', None, 'number', '30', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_page' None, [ColumnMetadata('wp_type', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_acctbal', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_shippriority', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'call_center' None, [ColumnMetadata('cc_company_name', None, 'text', '20', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_sales' None, [ColumnMetadata('ss_wholesale_cost', None, 'number', '12', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_returns' None, [ColumnMetadata('wr_order_number', None, 'number', '14', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'promotion' None, [ColumnMetadata('p_channel_email', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_sales' None, [ColumnMetadata('cs_warehouse_sk', None, 'number', '15', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'item' None, [ColumnMetadata('i_category_id', None, 'number', '12', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_sales' None, [ColumnMetadata('ss_ext_discount_amt', None, 'number', '15', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_linestatus', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'customer_address' None, [ColumnMetadata('ca_address_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_shipdate', None, 'date', '11', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_page' None, [ColumnMetadata('wp_link_count', None, 'number', '12', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_returns' None, [ColumnMetadata('wr_account_credit', None, 'number', '23', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_reversed_charge', None, 'number', '25', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_quantity', None, 'number', '19', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_page' None, [ColumnMetadata('wp_rec_end_date', None, 'date', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_refunded_hdemo_sk', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'partsupp' DescriptionMetadata('description', 'Partsupp data as defined by TPC-H'), [ColumnMetadata('ps_partkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'inventory' None, [ColumnMetadata('inv_item_sk', None, 'number', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'call_center' None, [ColumnMetadata('cc_call_center_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_comment', None, 'text', '16', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_acctbal', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'time_dim' None, [ColumnMetadata('t_minute', None, 'number', '5', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_size', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_sales' None, [ColumnMetadata('cs_ship_mode_sk', None, 'number', '14', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'promotion' None, [ColumnMetadata('p_promo_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store' None, [ColumnMetadata('s_street_number', None, 'text', '19', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_sales' None, [ColumnMetadata('ss_quantity', None, 'number', '11', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'customer' None, [ColumnMetadata('c_first_shipto_date_sk', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'item' None, [ColumnMetadata('i_manufact_id', None, 'number', '14', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_acctbal', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_name', None, 'text', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_sales' None, [ColumnMetadata('ss_promo_sk', None, 'number', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'call_center' None, [ColumnMetadata('cc_suite_number', None, 'text', '24', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_sales' None, [ColumnMetadata('cs_ship_customer_sk', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer_address' None, [ColumnMetadata('ca_zip', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store' None, [ColumnMetadata('s_street_number', None, 'text', '19', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_extendedprice', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_site' None, [ColumnMetadata('web_close_date_sk', None, 'number', '7', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'item' None, [ColumnMetadata('i_current_price', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store_returns' None, [ColumnMetadata('sr_return_amt', None, 'number', '12', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_web_site_sk', None, 'number', '14', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'time_dim' None, [ColumnMetadata('t_am_pm', None, 'text', '7', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_ext_ship_cost', None, 'number', '29', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_order_number', None, 'number', '17', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_warehouse_sk', None, 'number', '16', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_ext_tax', None, 'number', '27', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_site' None, [ColumnMetadata('web_rec_start_date', None, 'date', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer' None, [ColumnMetadata('c_last_name', None, 'text', '10', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'customer_demographics' None, [ColumnMetadata('cd_marital_status', None, 'text', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_returns' None, [ColumnMetadata('wr_returned_time_sk', None, 'number', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'date_dim' None, [ColumnMetadata('d_holiday', None, 'text', '17', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'income_band' None, [ColumnMetadata('ib_lower_bound', None, 'number', '2', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_returns' None, [ColumnMetadata('sr_customer_sk', None, 'number', '4', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_comment', None, 'text', '9', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_orderpriority', None, 'text', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_returning_customer_sk', None, 'number', '8', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer' None, [ColumnMetadata('c_birth_country', None, 'text', '15', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'call_center' None, [ColumnMetadata('cc_hours', None, 'text', '11', []), ColumnMetadata('cc_open_date_sk', None, 'number', '6', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_call_center_sk', None, 'number', '12', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_page' None, [ColumnMetadata('wp_char_count', None, 'number', '11', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_sales' None, [ColumnMetadata('cs_ship_date_sk', None, 'number', '3', [])], False, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'information_schema', 'tables' DescriptionMetadata('description', "The tables defined in this database that are accessible to the current user's role."), [ColumnMetadata('table_catalog', DescriptionMetadata('description', 'Database that the table belongs to'), 'text', '1', []), ColumnMetadata('table_schema', DescriptionMetadata('description', 'Schema that the table belongs to'), 'text', '2', []), ColumnMetadata('table_name', DescriptionMetadata('description', 'Name of the table'), 'text', '3', []), ColumnMetadata('table_owner', DescriptionMetadata('description', 'Name of the role that owns the table'), 'text', '4', []), ColumnMetadata('table_type', DescriptionMetadata('description', 'Whether the table is a base table, temporary table, or view'), 'text', '5', []), ColumnMetadata('is_transient', DescriptionMetadata('description', 'Whether this is a transient table'), 'text', '6', []), ColumnMetadata('clustering_key', DescriptionMetadata('description', 'Clustering key for the table'), 'text', '7', []), ColumnMetadata('row_count', DescriptionMetadata('description', 'Number of rows in the table'), 'number', '8', []), ColumnMetadata('bytes', DescriptionMetadata('description', 'Number of bytes accessed by a scan of the table'), 'number', '9', []), ColumnMetadata('retention_time', DescriptionMetadata('description', 'Number of days that historical data is retained for Time Travel'), 'number', '10', []), ColumnMetadata('self_referencing_column_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '11', []), ColumnMetadata('reference_generation', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '12', []), ColumnMetadata('user_defined_type_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '13', []), ColumnMetadata('user_defined_type_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '14', []), ColumnMetadata('user_defined_type_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '15', []), ColumnMetadata('is_insertable_into', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '16', []), ColumnMetadata('is_typed', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '17', []), ColumnMetadata('commit_action', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '18', []), ColumnMetadata('created', DescriptionMetadata('description', 'Creation time of the function'), 'timestamp_ltz', '19', []), ColumnMetadata('last_altered', DescriptionMetadata('description', 'Last altered time of the function'), 'timestamp_ltz', '20', []), ColumnMetadata('last_ddl', DescriptionMetadata('description', 'Last DDL time of the table'), 'timestamp_ltz', '21', []), ColumnMetadata('last_ddl_by', DescriptionMetadata('description', 'User name that performed the Last DDL of the table'), 'text', '22', []), ColumnMetadata('auto_clustering_on', DescriptionMetadata('description', 'Whether automatic clustering is on for the table'), 'text', '23', []), ColumnMetadata('comment', DescriptionMetadata('description', 'Comment for this table'), 'text', '24', []), ColumnMetadata('is_temporary', DescriptionMetadata('description', 'Whether this is a temporary table'), 'text', '25', []), ColumnMetadata('is_iceberg', DescriptionMetadata('description', 'Whether this is an Iceberg table'), 'text', '26', []), ColumnMetadata('is_dynamic', DescriptionMetadata('description', 'Whether this is a dynamic table'), 'text', '27', []), ColumnMetadata('is_immutable', DescriptionMetadata('description', 'Whether this is a READ ONLY table'), 'text', '28', [])], True, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'information_schema', 'columns' DescriptionMetadata('description', "The columns of tables defined in this database that are accessible to the current user's role."), [ColumnMetadata('table_catalog', DescriptionMetadata('description', 'Database that the table belongs to'), 'text', '1', []), ColumnMetadata('table_schema', DescriptionMetadata('description', 'Schema that the table belongs to'), 'text', '2', []), ColumnMetadata('table_name', DescriptionMetadata('description', 'Table that the column belongs to'), 'text', '3', []), ColumnMetadata('column_name', DescriptionMetadata('description', 'Name of the column'), 'text', '4', []), ColumnMetadata('ordinal_position', DescriptionMetadata('description', 'Ordinal position of the column in the table'), 'number', '5', []), ColumnMetadata('column_default', DescriptionMetadata('description', 'Default value of the column'), 'text', '6', []), ColumnMetadata('is_nullable', DescriptionMetadata('description', "'YES' if the column may contain NULL, 'NO' otherwise"), 'text', '7', []), ColumnMetadata('data_type', DescriptionMetadata('description', 'Data type of the column'), 'text', '8', []), ColumnMetadata('character_maximum_length', DescriptionMetadata('description', 'Maximum length in characters of string columns'), 'number', '9', []), ColumnMetadata('character_octet_length', DescriptionMetadata('description', 'Maximum length in bytes of string columns'), 'number', '10', []), ColumnMetadata('numeric_precision', DescriptionMetadata('description', 'Numeric precision of numeric columns'), 'number', '11', []), ColumnMetadata('numeric_precision_radix', DescriptionMetadata('description', 'Radix of precision of numeric columns'), 'number', '12', []), ColumnMetadata('numeric_scale', DescriptionMetadata('description', 'Scale of numeric columns'), 'number', '13', []), ColumnMetadata('datetime_precision', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '14', []), ColumnMetadata('interval_type', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '15', []), ColumnMetadata('interval_precision', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '16', []), ColumnMetadata('character_set_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '17', []), ColumnMetadata('character_set_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '18', []), ColumnMetadata('character_set_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '19', []), ColumnMetadata('collation_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '20', []), ColumnMetadata('collation_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '21', []), ColumnMetadata('collation_name', DescriptionMetadata('description', 'The name of collation, if present'), 'text', '22', []), ColumnMetadata('domain_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '23', []), ColumnMetadata('domain_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '24', []), ColumnMetadata('domain_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '25', []), ColumnMetadata('udt_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '26', []), ColumnMetadata('udt_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '27', []), ColumnMetadata('udt_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '28', []), ColumnMetadata('scope_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '29', []), ColumnMetadata('scope_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '30', []), ColumnMetadata('scope_ ...
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'information_schema', 'element_types' DescriptionMetadata('description', "The element types of structured array types defined in this database that are accessible to the current user's role."), [ColumnMetadata('object_catalog', DescriptionMetadata('description', 'Database that contains the object that uses this array type'), 'text', '1', []), ColumnMetadata('object_schema', DescriptionMetadata('description', 'Schema that contains the object that uses this array type'), 'text', '2', []), ColumnMetadata('object_name', DescriptionMetadata('description', 'Name of the object that uses this array type'), 'text', '3', []), ColumnMetadata('object_type', DescriptionMetadata('description', 'Type of the object that uses this array type'), 'text', '4', []), ColumnMetadata('collection_type_identifier', DescriptionMetadata('description', 'Type identifier'), 'text', '5', []), ColumnMetadata('data_type', DescriptionMetadata('description', 'Element data type'), 'text', '6', []), ColumnMetadata('character_maximum_length', DescriptionMetadata('description', 'Maximum length in characters for string types'), 'number', '7', []), ColumnMetadata('character_octet_length', DescriptionMetadata('description', 'Maximum length in bytes for string types'), 'number', '8', []), ColumnMetadata('numeric_precision', DescriptionMetadata('description', 'Numeric precision for numeric types'), 'number', '9', []), ColumnMetadata('numeric_precision_radix', DescriptionMetadata('description', 'Radix of precision for numeric types'), 'number', '10', []), ColumnMetadata('numeric_scale', DescriptionMetadata('description', 'Scale for numeric types'), 'number', '11', []), ColumnMetadata('datetime_precision', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '12', []), ColumnMetadata('interval_type', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '13', []), ColumnMetadata('interval_precision', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '14', []), ColumnMetadata('character_set_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '15', []), ColumnMetadata('character_set_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '16', []), ColumnMetadata('character_set_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '17', []), ColumnMetadata('collation_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '18', []), ColumnMetadata('collation_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '19', []), ColumnMetadata('collation_name', DescriptionMetadata('description', 'The name of collation, if present'), 'text', '20', []), ColumnMetadata('udt_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '21', []), ColumnMetadata('udt_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '22', []), ColumnMetadata('udt_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '23', []), ColumnMetadata('scope_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '24', []), ColumnMetadata('scope_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '25', []), ColumnMetadata('scope_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '26', []), ColumnMetadata('maximum_cardinality', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '27', []), ColumnMetadata('dtd_identifier', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '28', [])], True, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'information_schema', 'fields' DescriptionMetadata('description', "The fields of structured object and map types defined in this database that are accessible to the current user's role."), [ColumnMetadata('object_catalog', DescriptionMetadata('description', 'Database that contains the object that uses this object type'), 'text', '1', []), ColumnMetadata('object_schema', DescriptionMetadata('description', 'Schema that contains the object that uses this object type'), 'text', '2', []), ColumnMetadata('object_name', DescriptionMetadata('description', 'Name of the object that uses this object type'), 'text', '3', []), ColumnMetadata('object_type', DescriptionMetadata('description', 'Type of the object that uses this object type'), 'text', '4', []), ColumnMetadata('row_identifier', DescriptionMetadata('description', 'Type identifier'), 'text', '5', []), ColumnMetadata('field_name', DescriptionMetadata('description', 'Field name'), 'text', '6', []), ColumnMetadata('ordinal_position', DescriptionMetadata('description', 'Ordinal position'), 'number', '7', []), ColumnMetadata('data_type', DescriptionMetadata('description', 'Data type of the field'), 'text', '8', []), ColumnMetadata('character_maximum_length', DescriptionMetadata('description', 'Maximum length in characters of string fields'), 'number', '9', []), ColumnMetadata('character_octet_length', DescriptionMetadata('description', 'Maximum length in bytes of string fields'), 'number', '10', []), ColumnMetadata('numeric_precision', DescriptionMetadata('description', 'Numeric precision of numeric fields'), 'number', '11', []), ColumnMetadata('numeric_precision_radix', DescriptionMetadata('description', 'Radix of precision of numeric fields'), 'number', '12', []), ColumnMetadata('numeric_scale', DescriptionMetadata('description', 'Scale of numeric fields'), 'number', '13', []), ColumnMetadata('datetime_precision', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '14', []), ColumnMetadata('interval_type', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '15', []), ColumnMetadata('interval_precision', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '16', []), ColumnMetadata('character_set_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '17', []), ColumnMetadata('character_set_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '18', []), ColumnMetadata('character_set_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '19', []), ColumnMetadata('collation_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '20', []), ColumnMetadata('collation_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '21', []), ColumnMetadata('collation_name', DescriptionMetadata('description', 'The name of collation, if present'), 'text', '22', []), ColumnMetadata('udt_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '23', []), ColumnMetadata('udt_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '24', []), ColumnMetadata('udt_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '25', []), ColumnMetadata('scope_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '26', []), ColumnMetadata('scope_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '27', []), ColumnMetadata('scope_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '28', []), ColumnMetadata('maximum_cardinality', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'number', '29', []), ColumnMetadata('dtd_identifier', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'tex ...
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'information_schema', 'schemata' DescriptionMetadata('description', "The schemas defined in this database that are accessible to the current user's role."), [ColumnMetadata('catalog_name', DescriptionMetadata('description', 'Database that the schema belongs to'), 'text', '1', []), ColumnMetadata('schema_name', DescriptionMetadata('description', 'Name of the schema'), 'text', '2', []), ColumnMetadata('schema_owner', DescriptionMetadata('description', 'Name of the role that owns the schema'), 'text', '3', []), ColumnMetadata('is_transient', DescriptionMetadata('description', 'Whether this is a transient table'), 'text', '4', []), ColumnMetadata('is_managed_access', DescriptionMetadata('description', 'Whether this is a managed access schema'), 'text', '5', []), ColumnMetadata('retention_time', DescriptionMetadata('description', 'Number of days that historical data is retained for Time Travel'), 'number', '6', []), ColumnMetadata('default_character_set_catalog', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '7', []), ColumnMetadata('default_character_set_schema', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '8', []), ColumnMetadata('default_character_set_name', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '9', []), ColumnMetadata('sql_path', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '10', []), ColumnMetadata('created', DescriptionMetadata('description', 'Creation time of the schema'), 'timestamp_ltz', '11', []), ColumnMetadata('last_altered', DescriptionMetadata('description', 'Last altered time of the schema'), 'timestamp_ltz', '12', []), ColumnMetadata('comment', DescriptionMetadata('description', 'Comment for this schema'), 'text', '13', [])], True, [])
# 2024-07-24 20:53:59 record: TableMetadata('snowflake', 'snowflake_sample_data', 'information_schema', 'sequences' DescriptionMetadata('description', "The sequences defined in this database that are accessible to the current user's role."), [ColumnMetadata('sequence_catalog', DescriptionMetadata('description', 'Database that the sequence belongs to'), 'text', '1', []), ColumnMetadata('sequence_schema', DescriptionMetadata('description', 'Schema that the sequence belongs to'), 'text', '2', []), ColumnMetadata('sequence_name', DescriptionMetadata('description', 'Name of the sequence'), 'text', '3', []), ColumnMetadata('sequence_owner', DescriptionMetadata('description', 'Name of the role that owns the sequence'), 'text', '4', []), ColumnMetadata('data_type', DescriptionMetadata('description', 'Data type of the sequence'), 'text', '5', []), ColumnMetadata('numeric_precision', DescriptionMetadata('description', 'Numeric precision of the data type of the sequence'), 'number', '6', []), ColumnMetadata('numeric_precision_radix', DescriptionMetadata('description', 'Radix of the numeric precision of the data type of the sequence'), 'number', '7', []), ColumnMetadata('numeric_scale', DescriptionMetadata('description', 'Scale of the data type of the sequence'), 'number', '8', []), ColumnMetadata('start_value', DescriptionMetadata('description', 'Initial value of the sequence'), 'text', '9', []), ColumnMetadata('minimum_value', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '10', []), ColumnMetadata('maximum_value', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '11', []), ColumnMetadata('next_value', DescriptionMetadata('description', 'Next value that the sequence will produce'), 'text', '12', []), ColumnMetadata('increment', DescriptionMetadata('description', 'Increment of the sequence generator'), 'text', '13', []), ColumnMetadata('cycle_option', DescriptionMetadata('description', 'Not applicable for Snowflake.'), 'text', '14', []), ColumnMetadata('created', DescriptionMetadata('description', 'Creation time of the sequence'), 'timestamp_ltz', '15', []), ColumnMetadata('last_altered', DescriptionMetadata('description', 'Last altered time of the sequence'), 'timestamp_ltz', '16', []), ColumnMetadata('ordered', DescriptionMetadata('description', 'Whether or not the sequence is ordered'), 'text', '17', []), ColumnMetadata('comment', DescriptionMetadata('description', 'Comment for this sequence'), 'text', '18', [])], True, [])
# ...
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'region' DescriptionMetadata('description', 'Region data as defined by TPC-H'), [ColumnMetadata('r_name', None, 'text', '2', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_store_credit', None, 'number', '26', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'time_dim' None, [ColumnMetadata('t_time', None, 'number', '3', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_ext_ship_cost', None, 'number', '29', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'customer' None, [ColumnMetadata('c_email_address', None, 'text', '17', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer_demographics' None, [ColumnMetadata('cd_education_status', None, 'text', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store' None, [ColumnMetadata('s_division_id', None, 'number', '15', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_sales' None, [ColumnMetadata('cs_ship_hdemo_sk', None, 'number', '10', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_retailprice', None, 'number', '8', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'customer' DescriptionMetadata('description', 'Customer data as defined by TPC-H'), [ColumnMetadata('c_mktsegment', None, 'text', '7', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_shipdate', None, 'date', '11', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'time_dim' None, [ColumnMetadata('t_time_sk', None, 'number', '1', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer_address' None, [ColumnMetadata('ca_location_type', None, 'text', '13', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store_returns' None, [ColumnMetadata('sr_return_time_sk', None, 'number', '2', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_web_page_sk', None, 'number', '13', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'date_dim' None, [ColumnMetadata('d_current_week', None, 'text', '25', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_net_paid_inc_ship_tax', None, 'number', '33', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_comment', None, 'text', '7', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'customer_demographics' None, [ColumnMetadata('cd_education_status', None, 'text', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_return_quantity', None, 'number', '18', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_orderkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_returning_hdemo_sk', None, 'number', '10', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'household_demographics' None, [ColumnMetadata('hd_dep_count', None, 'number', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'customer' DescriptionMetadata('description', 'Customer data as defined by TPC-H'), [ColumnMetadata('c_mktsegment', None, 'text', '7', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_type', None, 'text', '5', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_orderpriority', None, 'text', '6', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_net_loss', None, 'number', '27', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_shipinstruct', None, 'text', '14', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_receiptdate', None, 'date', '13', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_size', None, 'number', '6', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_page' None, [ColumnMetadata('wp_creation_date_sk', None, 'number', '5', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'promotion' None, [ColumnMetadata('p_channel_details', None, 'text', '17', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_ship_cdemo_sk', None, 'number', '10', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_quantity', None, 'number', '5', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'item' None, [ColumnMetadata('i_brand_id', None, 'number', '8', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'promotion' None, [ColumnMetadata('p_purpose', None, 'text', '18', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'ship_mode' None, [ColumnMetadata('sm_code', None, 'text', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_suppkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'item' None, [ColumnMetadata('i_product_name', None, 'text', '22', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'customer' DescriptionMetadata('description', 'Customer data as defined by TPC-H'), [ColumnMetadata('c_custkey', None, 'number', '1', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_call_center_sk', None, 'number', '12', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_discount', None, 'number', '7', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_refunded_customer_sk', None, 'number', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_returnflag', None, 'text', '9', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store' None, [ColumnMetadata('s_store_name', None, 'text', '6', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_sales' None, [ColumnMetadata('ws_net_profit', None, 'number', '34', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_page' None, [ColumnMetadata('wp_image_count', None, 'number', '13', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_shippriority', None, 'number', '8', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_site' None, [ColumnMetadata('web_county', None, 'text', '21', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_returns' None, [ColumnMetadata('cr_returned_time_sk', None, 'number', '2', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'catalog_sales' None, [ColumnMetadata('cs_coupon_amt', None, 'number', '28', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'promotion' None, [ColumnMetadata('p_channel_demo', None, 'text', '16', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'catalog_returns' None, [ColumnMetadata('cr_item_sk', None, 'number', '3', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_returns' None, [ColumnMetadata('wr_return_tax', None, 'number', '17', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'date_dim' None, [ColumnMetadata('d_weekend', None, 'text', '18', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store' None, [ColumnMetadata('s_market_id', None, 'number', '11', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'customer' None, [ColumnMetadata('c_current_cdemo_sk', None, 'number', '3', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_returns' None, [ColumnMetadata('wr_returned_time_sk', None, 'number', '2', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'orders' DescriptionMetadata('description', 'Orders data as defined by TPC-H'), [ColumnMetadata('o_totalprice', None, 'number', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'date_dim' None, [ColumnMetadata('d_quarter_seq', None, 'number', '6', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store_sales' None, [ColumnMetadata('ss_customer_sk', None, 'number', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'part' DescriptionMetadata('description', 'Part data as defined by TPC-H'), [ColumnMetadata('p_brand', None, 'text', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'date_dim' None, [ColumnMetadata('d_week_seq', None, 'number', '5', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_linenumber', None, 'number', '4', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf10', 'customer' DescriptionMetadata('description', 'Customer data as defined by TPC-H'), [ColumnMetadata('c_address', None, 'text', '3', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store' None, [ColumnMetadata('s_market_desc', None, 'text', '13', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'web_site' None, [ColumnMetadata('web_street_name', None, 'text', '17', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'web_sales' None, [ColumnMetadata('ws_net_paid', None, 'number', '30', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store' None, [ColumnMetadata('s_county', None, 'text', '24', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1', 'supplier' DescriptionMetadata('description', 'Supplier data as defined by TPC-H'), [ColumnMetadata('s_address', None, 'text', '3', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf1000', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_returnflag', None, 'text', '9', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'store' None, [ColumnMetadata('s_geography_class', None, 'text', '12', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf100tcl', 'item' None, [ColumnMetadata('i_container', None, 'text', '20', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'item' None, [ColumnMetadata('i_category', None, 'text', '13', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpcds_sf10tcl', 'store' None, [ColumnMetadata('s_floor_space', None, 'number', '8', [])], False, [])
# 2024-07-24 20:54:00 record: TableMetadata('snowflake', 'snowflake_sample_data', 'tpch_sf100', 'lineitem' DescriptionMetadata('description', 'Lineitem data as defined by TPC-H'), [ColumnMetadata('l_extendedprice', None, 'number', '6', [])], False, [])
# 2024-07-24 20:54:00 Total extracted records: 1105
# 2024-07-24 20:54:00 Number of results in first chunk: 1
# 2024-07-24 20:54:00 No callbacks to notify
# 2024-07-24 20:54:00 Job completed
