# %%
import os

# Set up the Snowflake and PostgreSQL data sources
SNOWFLAKE_USER = os.environ.get("SNOWFLAKE_USER")
SNOWFLAKE_PASSWORD = os.environ.get("SNOWFLAKE_PASSWORD")
SNOWFLAKE_ACCOUNT = os.environ.get("SNOWFLAKE_ACCOUNT")
SNOWFLAKE_WAREHOUSE = os.environ.get("SNOWFLAKE_WAREHOUSE")
SNOWFLAKE_DATABASE = os.environ.get("SNOWFLAKE_DATABASE")
SNOWFLAKE_SCHEMA = os.environ.get("SNOWFLAKE_SCHEMA")
SNOWFLAKE_ROLE = os.environ.get("SNOWFLAKE_ROLE")

# %%
import logging
import sys

date_strftime_format = "%Y-%m-%y %H:%M:%S"
logging.basicConfig(
    stream=sys.stdout,
    level=logging.INFO,
    format="%(asctime)s %(message)s",
    datefmt=date_strftime_format,
)

# %%
from ryoma.datasource.snowflake import SnowflakeDataSource

sf_datasource = SnowflakeDataSource(
    user=SNOWFLAKE_USER,
    password=SNOWFLAKE_PASSWORD,
    account=SNOWFLAKE_ACCOUNT,
    warehouse=SNOWFLAKE_WAREHOUSE,
    database=SNOWFLAKE_DATABASE,
    db_schema=SNOWFLAKE_SCHEMA,
    role="ACCOUNTADMIN",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ryoma.datasource.snowflake import SnowflakeDataSource
#       3 sf_datasource = SnowflakeDataSource(
#       4     user=SNOWFLAKE_USER,
#       5     password=SNOWFLAKE_PASSWORD,
#    (...)
#      10     role="ACCOUNTADMIN",
#      11 )
#
# File ~/dev/ryoma/ryoma/datasource/snowflake.py:6
#       3 import logging
#       5 import ibis
# ----> 6 from databuilder.extractor.sql_alchemy_extractor import SQLAlchemyExtractor
#       7 from databuilder.job.job import DefaultJob
#       8 from databuilder.loader.base_loader import Loader
#
# ModuleNotFoundError: No module named 'databuilder'

# %%
sf_datasource

# %%
# sf_datasource.query("select * from SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.orders limit 3")

# %%
from databuilder.loader.generic_loader import GenericLoader

# %%
sf_datasource.get_catalog(loader=GenericLoader())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sf_datasource.crawl_data_catalog(loader=GenericLoader(conf={}))
#
# TypeError: GenericLoader() takes no arguments

# %%
import ibis

# %%
conn = ibis.postgres.connect(
    host="localhost",
    port=5432,
    database="postgres",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 conn = ibis.postgres.connect(
#       2     host="localhost",
#       3     port=5432,
#       4     database="postgres",
#       5 )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/ibis/__init__.py:107, in __getattr__.<locals>.connect(*args, **kwargs)
#     106 def connect(*args, **kwargs):
# --> 107     return backend.connect(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/ibis/backends/base/__init__.py:847, in BaseBackend.connect(self, *args, **kwargs)
#     824 """Connect to the database.
#     825
#     826 Parameters
#    (...)
#     844     An instance of the backend
#     845 """
#     846 new_backend = self.__class__(*args, **kwargs)
# --> 847 new_backend.reconnect()
#     848 return new_backend
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/ibis/backends/base/__init__.py:862, in BaseBackend.reconnect(self)
#     860 def reconnect(self) -> None:
#     861     """Reconnect to the database already configured with connect."""
# --> 862     self.do_connect(*self._con_args, **self._con_kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/ibis/backends/postgres/__init__.py:119, in Backend.do_connect(self, host, user, password, port, database, schema, url, driver)
#     116 if schema is not None:
#     117     connect_args["options"] = f"-csearch_path={schema}"
# --> 119 engine = sa.create_engine(
#     120     alchemy_url, connect_args=connect_args, poolclass=sa.pool.StaticPool
#     121 )
#     123 @sa.event.listens_for(engine, "connect")
#     124 def connect(dbapi_connection, connection_record):
#     125     with dbapi_connection.cursor() as cur:
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/sqlalchemy/engine/create.py:599, in create_engine(url, **kwargs)
#     597         if k in kwargs:
#     598             dbapi_args[k] = pop_kwarg(k)
# --> 599     dbapi = dbapi_meth(**dbapi_args)
#     601 dialect_args["dbapi"] = dbapi
#     603 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:690, in PGDialect_psycopg2.import_dbapi(cls)
#     688 @classmethod
#     689 def import_dbapi(cls):
# --> 690     import psycopg2
#     692     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
conn.list_schemas()

# %%
conn.sql("select * from information_schema.tables limit 3")
# Out:
# SQLQueryResult
#   query:
#     select * from information_schema.tables limit 3
#   schema:
#     table_catalog                string
#     table_schema                 string
#     table_name                   string
#     table_type                   string
#     self_referencing_column_name string
#     reference_generation         string
#     user_defined_type_catalog    string
#     user_defined_type_schema     string
#     user_defined_type_name       string
#     is_insertable_into           string
#     is_typed                     string
#     commit_action                string

# %%
print(ibis.__version__)
# Out:
# 9.0.0
