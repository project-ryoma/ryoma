# %%
from aita.datasource.file import FileDataSource

# %%
f = FileDataSource("../data/creditcard.csv", name="creditcard", format="csv")

# %%
tb = f.to_arrow()

# %%
tb.to_pandas()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
from aita.datasource.postgresql import PostgreSqlDataSource

pq = PostgreSqlDataSource(connection_url="postgresql://@localhost:5432/postgres")

# %%
from aita.agent.sql import SqlAgent

agent = SqlAgent(datasource=pq, model_id="gpt-3.5-turbo", allow_extract_metadata=True)
agent.chat(f"I want to create table with the data schema {tb.schema} in postgresql with all capitals on column type", allow_run_tool=True)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 4
#       1 from aita.agent.sql import SqlAgent
#       3 agent = SqlAgent(datasource=pq, model_id="gpt-3.5-turbo", allow_extract_metadata=True)
# ----> 4 agent.chat(f"I want to create table with the data schema {tb.schema} in postgresql with all capitals on column type", allow_run_tool=True)
#
# File ~/dev/aita/monorepo/aita/agent/base.py:82, in AitaAgent.chat(self, question, allow_run_tool)
#      80 run_tool_results = []
#      81 for tool in chat_result.additional_kwargs["tool_calls"]:
# ---> 82     run_tool_result = self.run_tool(tool["function"])
#      83     run_tool_results.append(run_tool_result)
#      84 return run_tool_results
#
# File ~/dev/aita/monorepo/aita/agent/base.py:92, in AitaAgent.run_tool(self, tool_spec)
#      90 if isinstance(arguments, str):
# ...

# %%
pq.ingest("creditcard", tb)
# Out:
# 284807

# %%
from pyarrow.csv import read_csv

# %%
t = read_csv("./creditcard.csv")

# %%
t.to_pandas()
